# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN'] #iso_code 'JPN'のデータだけを取り出す
JP2 = JP[["location","date","total_cases","new_cases","total_deaths","new_deaths"]]
JP2.to_csv('JP_record5.csv')

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-11-01:2020-11-24']
JPdf.to_csv('JP_Record_Nov.csv')

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-11-01:2020-11-24']

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-11-01:2020-11-24']
print(JPdf)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, location, date, total_cases, new_cases, total_deaths, new_deaths]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-11-1:2020-11-24']
print(JPdf)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, location, date, total_cases, new_cases, total_deaths, new_deaths]
# Index: []

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')]
print(JPdf)
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 184       27740    Japan  2020-07-02      18874.0      151.0         975.0
# 185       27741    Japan  2020-07-03      19068.0      194.0         976.0
# 186       27742    Japan  2020-07-04      19282.0      214.0         977.0
# 187       27743    Japan  2020-07-05      19522.0      240.0         977.0
# 188       27744    Japan  2020-07-06      19775.0      253.0         977.0
# 189       27745    Japan  2020-07-07      19981.0      206.0         978.0
#
#      new_deaths
# 184         1.0
# 185         1.0
# 186         1.0
# 187         0.0
# 188         0.0
# 189         1.0

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN']
JP2 = JP[["location","date","total_cases","new_cases","total_deaths","new_deaths"]]
JP3 = df[('2020-11-01' < df['date']) & (df['date'] < '2020-11-24')]
print(JP3)
# Out:
#        iso_code continent       location        date  total_cases  new_cases  \
# 307         AFG      Asia    Afghanistan  2020-11-02      41633.0      132.0
# 308         AFG      Asia    Afghanistan  2020-11-03      41728.0       95.0
# 309         AFG      Asia    Afghanistan  2020-11-04      41814.0       86.0
# 310         AFG      Asia    Afghanistan  2020-11-05      41935.0      121.0
# 311         AFG      Asia    Afghanistan  2020-11-06      41975.0       40.0
# 312         AFG      Asia    Afghanistan  2020-11-07      42033.0       58.0
# 313         AFG      Asia    Afghanistan  2020-11-08      42159.0      126.0
# 314         AFG      Asia    Afghanistan  2020-11-09      42239.0       80.0
# 315         AFG      Asia    Afghanistan  2020-11-10      42463.0      224.0
# 316         AFG      Asia    Afghanistan  2020-11-11      42463.0        0.0
# 317         AFG      Asia    Afghanistan  2020-11-12      42609.0      146.0
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN']
print(JP)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 27556      JPN      Asia    Japan  2019-12-31          NaN        0.0
# 27557      JPN      Asia    Japan  2020-01-01          NaN        0.0
# 27558      JPN      Asia    Japan  2020-01-02          NaN        0.0
# 27559      JPN      Asia    Japan  2020-01-03          NaN        0.0
# 27560      JPN      Asia    Japan  2020-01-04          NaN        0.0
# 27561      JPN      Asia    Japan  2020-01-05          NaN        0.0
# 27562      JPN      Asia    Japan  2020-01-06          NaN        0.0
# 27563      JPN      Asia    Japan  2020-01-07          NaN        0.0
# 27564      JPN      Asia    Japan  2020-01-08          NaN        0.0
# 27565      JPN      Asia    Japan  2020-01-09          NaN        0.0
# 27566      JPN      Asia    Japan  2020-01-10          NaN        0.0
# 27567      JPN      Asia    Japan  2020-01-11          NaN        0.0
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN' & df[('2020-11-01' < df['date']) & (df['date'] < '2020-11-24')]]
print(JP)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/internals.py in eval(self, func, other, errors, try_cast, mgr)
#    1354             values, values_mask, other, other_mask = self._try_coerce_args(
# -> 1355                 transf(values), other)
#    1356         except TypeError:
#
# /usr/lib/python3/dist-packages/pandas/core/internals.py in _try_coerce_args(self, values, other)
#     741                 type(other).__name__,
# --> 742                 type(self).__name__.lower().replace('Block', '')))
#     743
#
# TypeError: cannot convert str to an floatblock
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN']
JP2 = JP[["location","date","total_cases","new_cases","total_deaths","new_deaths"]]
JP3 = JP2[('2020-11-01' < df['date']) & (df['date'] < '2020-11-24')]
print(JP3)
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths
# 27863    Japan  2020-11-02     101813.0      667.0        1774.0         8.0
# 27864    Japan  2020-11-03     102281.0      468.0        1780.0         6.0
# 27865    Japan  2020-11-04     102900.0      619.0        1786.0         6.0
# 27866    Japan  2020-11-05     103838.0      938.0        1794.0         8.0
# 27867    Japan  2020-11-06     104782.0      944.0        1806.0        12.0
# 27868    Japan  2020-11-07     105914.0     1132.0        1809.0         3.0
# 27869    Japan  2020-11-08     107086.0     1172.0        1812.0         3.0
# 27870    Japan  2020-11-09     108084.0      998.0        1818.0         6.0
# 27871    Japan  2020-11-10     108983.0      899.0        1829.0        11.0
# 27872    Japan  2020-11-11     110156.0     1173.0        1841.0        12.0
# 27873    Japan  2020-11-12     111711.0     1555.0        1851.0        10.0
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'DEU']
print(JP)
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 19909      DEU    Europe  Germany  2020-01-23          NaN        0.0
# 19910      DEU    Europe  Germany  2020-01-24          NaN        0.0
# 19911      DEU    Europe  Germany  2020-01-25          NaN        0.0
# 19912      DEU    Europe  Germany  2020-01-26          NaN        0.0
# 19913      DEU    Europe  Germany  2020-01-27          1.0        1.0
# 19914      DEU    Europe  Germany  2020-01-28          4.0        3.0
# 19915      DEU    Europe  Germany  2020-01-29          4.0        0.0
# 19916      DEU    Europe  Germany  2020-01-30          4.0        0.0
# 19917      DEU    Europe  Germany  2020-01-31          5.0        1.0
# 19918      DEU    Europe  Germany  2020-02-01          8.0        3.0
# 19919      DEU    Europe  Germany  2020-02-02         10.0        2.0
# 19920      DEU    Europe  Germany  2020-02-03         12.0        2.0
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
IND = df[df["iso_code"] == 'IDN'] 
IND2 = IND[["location","date","new_cases","new_deaths","icu_patients","people_fully_vaccinated","population"]]
IND2.to_csv('IND_record.csv')

# %%
import pandas as pd
df = pd.read_csv('~/mypj/IND_record.csv')
IND3 = JP2[('2020-11-01' < df['date']) & (df['date'] < '2020-11-24')]
