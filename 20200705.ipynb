# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
JP = df[df["iso_code"] == 'JPN'] #iso_code 'JPN'のデータだけを取り出す
JP2 = JP[["location","date","total_cases","new_cases","total_deaths","new_deaths"]]
JP2.to_csv('JP_record5.csv')

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
UK = df[df["iso_code"] == 'GBR'] #iso_code 'JPN'のデータだけを取り出す
UK2 = UK[["location","date","total_cases","new_cases","total_deaths","new_deaths"]]
UK2.to_csv('UK_record5.csv')

# %%
#Make a graph for the data of number of new deaths in UK dai;y basis
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('UK_record5.csv')
df.plot.bar(y=['new_deaths'])

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-05-25:2020-07-08'] 
df.plot.bar(y=['new_deaths'])

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[df["date"] == '2020-07-01:2020-07-08'] 
df.plot.bar(y=['new_deaths'])

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JP = df[df["date"] == '2020-07-01:2020-07-08'] 
jp.plot.bar(y=['new_deaths'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fedfb53c1221> in <module>()
#       3 df = pd.read_csv('JP_record5.csv')
#       4 JP = df[df["date"] == '2020-07-01:2020-07-08']
# ----> 5 jp.plot.bar(y=['new_deaths'])
#
# NameError: name 'jp' is not defined

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
print(JPdf)
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 184       13470    Japan  2020-07-02      18874.0      151.0         975.0
# 185       13471    Japan  2020-07-03      19068.0      194.0         976.0
# 186       13472    Japan  2020-07-04      19282.0      214.0         977.0
# 187       13473    Japan  2020-07-05      19522.0      240.0         977.0
#
#      new_deaths
# 184         1.0
# 185         1.0
# 186         1.0
# 187         0.0

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')]
print(JPdf)
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 184       13470    Japan  2020-07-02      18874.0      151.0         975.0
# 185       13471    Japan  2020-07-03      19068.0      194.0         976.0
# 186       13472    Japan  2020-07-04      19282.0      214.0         977.0
# 187       13473    Japan  2020-07-05      19522.0      240.0         977.0
#
#      new_deaths
# 184         1.0
# 185         1.0
# 186         1.0
# 187         0.0

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
JPdf.plot.bar(y=['new_deaths'])

# %%
import pandas as pd
df = pd.read_csv('JP_record5.csv')
print (df.query('2020-04-01' < df['date'] < '2020-04-07'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0f02be5c5d1f> in <module>()
#       1 import pandas as pd
#       2 df = pd.read_csv('JP_record5.csv')
# ----> 3 print (df.query('2020-04-01' < df['date'] < '2020-04-07'))
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
JPdf.plot.bar(x=['date'], y=['new_deaths'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-6dcde6916a7e> in <module>()
#       3 df = pd.read_csv('JP_record5.csv')
#       4 JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head()
# ----> 5 JPdf.plot.bar(x=['date'], y=['new_deaths'])
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    3088             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3089         """
# -> 3090         return self(kind='bar', x=x, y=y, **kwds)
#    3091
#    3092     def barh(self, x=None, y=None, **kwds):
#
# /usr/lib/python3/dist-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
JPdf.plot.bar(y=['new_deaths'])

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')]
JPdf.plot.bar(x='date', y='new_cases')
JPdf
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 184       13470    Japan  2020-07-02      18874.0      151.0         975.0
# 185       13471    Japan  2020-07-03      19068.0      194.0         976.0
# 186       13472    Japan  2020-07-04      19282.0      214.0         977.0
# 187       13473    Japan  2020-07-05      19522.0      240.0         977.0
#
#      new_deaths
# 184         1.0
# 185         1.0
# 186         1.0
# 187         0.0

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-06-01' < df['date']) & (df['date'] < '2020-07-08')]
JPdf.plot.bar(x='date', y='new_cases')
JPdf
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 154       13440    Japan  2020-06-02      16930.0       46.0         894.0
# 155       13441    Japan  2020-06-03      16986.0       56.0         900.0
# 156       13442    Japan  2020-06-04      17018.0       32.0         903.0
# 157       13443    Japan  2020-06-05      17064.0       46.0         907.0
# 158       13444    Japan  2020-06-06      17103.0       39.0         914.0
# 159       13445    Japan  2020-06-07      17141.0       38.0         916.0
# 160       13446    Japan  2020-06-08      17174.0       33.0         916.0
# 161       13447    Japan  2020-06-09      17210.0       36.0         916.0
# 162       13448    Japan  2020-06-10      17251.0       41.0         919.0
# 163       13449    Japan  2020-06-11      17292.0       41.0         920.0
# 164       13450    Japan  2020-06-12      17332.0       40.0         922.0
# ...

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
JPdf.plot.bar(y=['new_cases'])

# %%
# %matplotlib inline 
import pandas as pd
df = pd.read_csv('JP_record5.csv')
JPdf = df[('2020-07-01' < df['date']) & (df['date'] < '2020-07-08')].head() 
JPdf.plot.bar(y=['new_cases'])
JPdf
# Out:
#      Unnamed: 0 location        date  total_cases  new_cases  total_deaths  \
# 184       13470    Japan  2020-07-02      18874.0      151.0         975.0
# 185       13471    Japan  2020-07-03      19068.0      194.0         976.0
# 186       13472    Japan  2020-07-04      19282.0      214.0         977.0
# 187       13473    Japan  2020-07-05      19522.0      240.0         977.0
#
#      new_deaths
# 184         1.0
# 185         1.0
# 186         1.0
# 187         0.0
