# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
df.head() #先頭５行を表形式で表示する
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-25          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-26          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-27          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         0.0                  NaN
# 1                 NaN           NaN         0.0                  NaN
# 2                 NaN           NaN         0.0                  NaN
# 3                 NaN           NaN         0.0                  NaN
# 4                 NaN           NaN         0.0                  NaN
#
#             ...             gdp_per_capita  extreme_poverty  \
# 0           ...                   1803.987              NaN
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
df.info() #細かい情報を表示する
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60480 entries, 0 to 60479
# Data columns (total 50 columns):
# iso_code                              60164 non-null object
# continent                             59847 non-null object
# location                              60480 non-null object
# date                                  60480 non-null object
# total_cases                           51741 non-null float64
# new_cases                             60357 non-null float64
# new_cases_smoothed                    59401 non-null float64
# total_deaths                          43883 non-null float64
# new_deaths                            60357 non-null float64
# new_deaths_smoothed                   59401 non-null float64
# total_cases_per_million               51440 non-null float64
# new_cases_per_million                 60041 non-null float64
# new_cases_smoothed_per_million        59090 non-null float64
# total_deaths_per_million              43595 non-null float64
# ...

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
df['iso_code']
# Out:
# 0        AFG
# 1        AFG
# 2        AFG
# 3        AFG
# 4        AFG
# 5        AFG
# 6        AFG
# 7        AFG
# 8        AFG
# 9        AFG
# 10       AFG
# 11       AFG
# 12       AFG
# 13       AFG
# 14       AFG
# 15       AFG
# 16       AFG
# 17       AFG
# 18       AFG
# 19       AFG
# 20       AFG
# 21       AFG
# 22       AFG
# 23       AFG
# 24       AFG
# 25       AFG
# 26       AFG
# 27       AFG
# 28       AFG
# 29       AFG
#         ...
# 60450    ZWE
# 60451    ZWE
# 60452    ZWE
# 60453    ZWE
# 60454    ZWE
# 60455    ZWE
# 60456    ZWE
# 60457    ZWE
# 60458    ZWE
# 60459    ZWE
# 60460    ZWE
# 60461    ZWE
# 60462    ZWE
# 60463    ZWE
# 60464    ZWE
# 60465    ZWE
# 60466    ZWE
# 60467    ZWE
# 60468    ZWE
# 60469    ZWE
# 60470    ZWE
# 60471    ZWE
# 60472    ZWE
# 60473    ZWE
# 60474    ZWE
# 60475    ZWE
# 60476    ZWE
# 60477    ZWE
# 60478    ZWE
# 60479    ZWE
# Name: iso_code, Length: 60480, dtype: object

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/owid-covid-data.csv')
df['iso_code']=='GBR'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 60450    False
# 60451    False
# 60452    False
# 60453    False
# 60454    False
# 60455    False
# 60456    False
# 60457    False
# 60458    False
# 60459    False
# 60460    False
# 60461    False
# 60462    False
# 60463    False
# 60464    False
# 60465    False
# 60466    False
# 60467    False
# 60468    False
# 60469    False
# 60470    False
# 60471    False
# 60472    False
# 60473    False
# 60474    False
# 60475    False
# 60476    False
# ...
